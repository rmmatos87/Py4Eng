# %% [markdown]
# <img src='https://drive.google.com/uc?export=view&id=1SAQBpoqGzB5CT9lwxj1T0h0qVU5p6sdW' width=200 style="float:center">
#
# # MatplotLib
# ---
# Biblioteca para criar gráficos 2D em um estilo próximo ao do Matlab®
#
# **Índice:**
# 1. [Básico](#I.-Básico)
# 2. [Personalizando](#II.-Personalizando)
# 3. [Histogramas](#III.-Histogramas)
# 4. [Tutoriais](#IV.-Tutoriais)
#
# **Fontes**
# * [MatplotLib](https://matplotlib.org/)
# * [Aulas UFRJ](https://dcc.ufrj.br/~pythonufrj/aulas-python2_37/aula8_teorica.pdf)

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rCKD6-pmFyE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rCKD6-pmFyE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Importando bibliotecas

# %%
import matplotlib.pyplot as plt
import numpy as np

import os

# %% [markdown]
# ## I. Básico
# ---
# **Índice:**
# 1. [Tela em branco](#1-Tela-em-branco)
# 2. [Método `plot()`](#2-Método-plot())
# 3. [Salvando a figura](#3-Salvando-a-figura)
#
# **Vídeo:** https://youtu.be/rCKD6-pmFyE

# %% [markdown]
# ### 1 Tela em branco
# Criando tela em branco
# ```python
# fig, ax = plt.subplots()
# ```
# * `fig` é uma instância de figura (”quadro em branco”)
# * `ax` é um frame no qual você pode plotar algo

# %%
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# ### 2 Método `plot()`
# Plotando a curva:
# $$
# \{x \in \mathbb{R}\ |\ 0 \le x \le 10\} \\
# y = \sin{x}
# $$
# `len(x)= 200`

# %%
x = np.linspace(0, 10, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(
    x, y,
    'b-', # b: linha azul;
          # -: estilo da linha;
    linewidth=5 # espessura da linha
)
plt.show()

# %% [markdown]
# Plotando duas curvas
# $$
# \{x \in \mathbb{R}\ |\ 0 \le x \le 10\} \\
# y = \sin{x}
# z = \cos(x)
# $$
# `len(x)= 200`

# %%
x = np.linspace(0, 10, 200)
y = np.sin(x)
z = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, y, 'b-', linewidth=5) # plotando o seno
ax.plot(x, z, 'r--', linewidth=3) # plotando o cosseno
plt.show()

# %% [markdown]
# **Fontes:**
# * [`matplotlib.pyplot.plot`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html?highlight=plot#matplotlib.pyplot.plot)
# * [`linestyle`](https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D.set_linestyle)
# * [`markers`](https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers)
# * [`colors`](https://matplotlib.org/stable/api/colors_api.html?highlight=color)

# %% [markdown]
# ### 3 Salvando a figura
# Enquanto o comando `plt.show()` faz com que a figura seja mostrada, o comando [`plt.savefig()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html?highlight=savefig#matplotlib.pyplot.savefig) faz com que ela seja salva.
# ```python
# savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches=None, pad_inches=0.1,
#         frameon=None, metadata=None)
# ```

# %%
x = np.linspace(0, 10, 200)
y = np.sin(x)
z = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, y, 'b-', linewidth=5) # plotando o seno
ax.plot(x, z, 'r--', linewidth=3) # plotando o cosseno

plt.savefig('figura1.png')

# %% [markdown]
# #### Exercício 1
# * Teste outras cores e formatos para o exemplo dado.
# * Altere o número de pontos.
# * Plote as funções seno e cosseno no mesmo gráfico, em cores e formatos diferentes.
# * Plote as funções cosseno e tangente de forma que as cores e formatos de cada plot sejam distintas. Varie o número de pontos usados na geração dos gráficos.
# * Salve os gráficos resultantes em arquivos.

# %% [markdown]
# ## II. Personalizando
# ---
# As representações utilizando o matplotlib são bem customizáveis considerando-se os métodos disponíveis na biblioteca.
#
# **Índice:**
# 1. [Rótulos e Legendas](#1-Rótulos-e-Legendas)
# 2. [Utilizando LaTeX](#2-Utilizando-LaTeX)
# 3. [Gráficos descontínuos](#3-Gráficos-descontínuos)
# 4. [Subplots](#4-Subplots)
#
# **Vídeo:** https://youtu.be/d98tOVvY278

# %% [markdown]
# ### 1 Rótulos e Legendas
# * `plt.subplots`
#     * `figsize` - `tuple` - ajusta o tamanho da figura (largura, altura)
# * `ax.plot`
#     * `label` - `str` - nomeia a curva
# * `plt.xlabel` - `str` - nomeia o eixo X
# * `plt.ylabel` - `str` - nomeia o eixo Y
# * [`ax.legend`](https://matplotlib.org/stable/api/legend_api.html?highlight=legend#module-matplotlib.legend) - insere a legenda

# %%
x = np.linspace(0, 10, 200)
y = np.sin(x)
z = np.cos(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, 'b-', linewidth=5, label='y = sin(x)', alpha=.6) # plotando o seno
ax.plot(x, z, 'r--', linewidth=3, label='y = cos(x)') # plotando o cosseno

plt.xlabel('X')
plt.ylabel('Y')

ax.legend(loc='upper center') # mostra a legenda com a localização definida

plt.show()

# %% [markdown]
# ### 2 Utilizando LaTeX
# **Fontes:**
# * [LaTeX](https://www.math.ubc.ca/~pwalls/math-python/jupyter/latex/)

# %%
x = np.linspace(0, 10, 200)
y = np.sin(x)
z = np.cos(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, 'b-', linewidth=5, label='$y = \sin{(x)}$', alpha=.6) # Utilizando LaTeX
ax.plot(x, z, 'r--', linewidth=3, label='y = cos(x)') # plotando o cosseno

plt.xlabel('X')
plt.ylabel('Y')

ax.legend(loc='upper center') # mostra a legenda com a localização definida

plt.show()

# %% [markdown]
# * `ax.set_title` ou `plt.title` - str - Insere um título no gráfico
# * `ax.set_yticks` ou `plt.yticks` - list - Escolhe quais as marcações no eixo Y

# %%
x = np.linspace(0, 10, 200)
y = np.sin(x)
z = np.cos(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, 'b-', linewidth=5, label='$y = \sin{(x)}$', alpha=.6) # Utilizando LaTeX
ax.plot(x, z, 'r--', linewidth=3, label='y = cos(x)') # plotando o cosseno

plt.xlabel('X')
plt.ylabel('Y')

ax.legend(loc='upper center') # mostra a legenda com a localização definida

ax.set_title('Teste')
ax.set_yticks(range(-1, 2))

plt.show()

# %% [markdown]
# #### Exercício 2
# Crie um array com números do intervalo $[0., 5.)$ ($step = 0.2$), e plote as funções da tabela abaixo, inclua os rótulos e legendas conforme julgar necessário.
#
# |Função|Formato|
# |-|-|
# |$$f(x) = x$$|traços vermelhos|
# |$$g(x) = x^2$$|quadrados azuis|
# |$$h(x) = x^3$$| triângulos verdes|

# %% [markdown]
# #### Exercício 3
# Considerando que você está usando $100$ pontos no intervalo $[−10,10]$, plote as funções $seno$ e $cosseno$ considerando:
# * Figura:
#     * título: "Seno e Cosseno"
#     * legenda: $[y = \sin{(x)},\ y = \cos{(x)}]$
#     * traços de y: $[-1,\ 0,\ 1]$
#     * tamanho: $(20,\ 5)$
# * Seno
#     * tracejado vermelho
# * Cosseno
#     * linha cheia verde

# %% [markdown]
# #### Exercício 4
# Faça o gráfico de $y = x^2$ onde, para $x < 0$ a linha é tracejada vermelha e para $x \ge 0$ a linha é cheia e azul. Colque rótulos e legendas.

# %% [markdown]
# ### 3 Gráficos descontínuos
# Para funções que apresentem descontinuidades podemos representar as descontinuidades com diferentes cores:
# $$y = \bigg\{ \begin{matrix} -x^2 & x \le 0 \\ x^2 + 1 & x > 0 \end{matrix}$$

# %%
x = np.linspace(-2, 2, 200)
y = np.zeros_like(x)
y[x <= 0] = -x[x <= 0]**2
y[x > 0] = x[x <= 0]**2 + 1

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, 'x-')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# Para eliminar a conexão entre os pontos de descontinuidades inserimos um $NaN$ (*Not a Number*). Sabemos que a derivada da função aumenta quando ocorre a discontinuidade, portanto vamos observar a derivada discreta da função.
#
# * `np.diff` - `np.ndarray` - faz a diferenças entre os elementos subsequentes do vetor

# %%
x = np.linspace(-2, 2, 200)
y = np.zeros_like(x)
y[x <= 0] = -x[x <= 0]**2
y[x > 0] = x[x <= 0]**2 + 1

dydx = np.diff(y)/np.diff(x) # retorna uma dimensão a menos que o vetor original

fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(x[1:], dydx, 'r3-', label='$\Delta{y}/\Delta{x}$')

ax.legend()

plt.show()

# %% [markdown]
# Um modo simples de encontrar uma descontinuidade pode ser encontrar a maior derivada. Neste ponto será adicionado o `np.nan` para mostrar a descontinuidade.
# ```python
# np.insert(
#     arr,      # array onde o valor será inserido
#     obj,      # será inserido antes das posições definidas por este iterável ou inteiro
#     values,   # valor a ser inserido
#     axis=None # eixo para a inserção
# )
# ```

# %%
x = np.linspace(-2, 2, 200)
y = np.zeros_like(x)
y[x <= 0] = -x[x <= 0]**2
y[x > 0] = x[x <= 0]**2 + 1

dydx = np.diff(y)/np.diff(x) # retorna uma dimensão a menos que o vetor original

descontinuidade = np.where(dydx == dydx.max())[0]

x = np.insert(x, descontinuidade + 1, np.nan)
y = np.insert(y, descontinuidade + 1, np.nan)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, 'x-')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# #### Exercício 5
# Considere as seguintes informações:
# * $x \in [-10,\ 10]$
# * $len{(x)} = 100$
# * $y = x^3$
# * Cor da linha do gráfico
#     * $-3 \le x \le 3$ - Vermelha
#     * Caso contrário - Azul
#
# Crie este gráfico com legenda e para diferenciar os intervalos coloridos de maneira diferente.

# %% [markdown]
# ### 4 Subplots
# Subplots são matrizes de plots em suas linhas e colunas.
# ```python
# plt.subplot(
#     nrows=1,          # número de gráficos na horizontal
#     ncols=1,          # número de gráficos na vertical
#     sharex=False,     # utilizar o mesmo eixo - X
#     sharey=False,     # utilizar o mesmo eixo - Y
#     squeeze=True,     # modifica a saída de eixos para um vetor achatado (1-D)
#     subplot_kw=None,  # argumentos de matplotlib.pyplot.subplot
#     gridspec_kw=None, # argumentos de matplotlib.pyplot.grid
#     **fig_kw          # argumentos de matplotlib.pyplot.figure
# )
# ```

# %%
n_pontos = 1000
y = np.random.randn(n_pontos)

fig, ax = plt.subplots(1, 2, sharey=True, figsize=(20,5))

n_bins = 30 # número de colunas

ax[0].hist(y, bins=n_bins)
ax[0].set_title('Histograma com %d colunas'%n_bins)
ax[1].hist(y, bins=20, facecolor='r')
ax[1].set_title('Histograma com 20 colunas')

plt.show()

# %% [markdown]
# ## III. Histogramas
# ---
# Histogramas representam a frequência de determinado valor no conjunto de dados.
#
# **Vídeo:** https://youtu.be/L2sxYpLDTh8
#
# A seguir vemos um histograma de uma distrinuição normal

# %%
n_pontos = 1000
y = np.random.randn(n_pontos)

fig, ax = plt.subplots()

n_bins = 30 # número de colunas

ax.hist(y, bins=n_bins) # gerando o histograma

plt.show()

# %% [markdown]
# #### Exercício 6
# Três medidores de nível (`LT-01`, `LT-02`, `LT-03`) são instalados em um tanque. Cada um deles tem um princípio de funcionamento diferente. Também são diferentes os erros de medição.
# * Crie uma função que plote as 3 medições de nível no intervalo de tempo $t_0 \rightarrow t_1$ - `plotar_niveis(t_0, t_1)`
# * Disponibilize uma entrada para função que controle se o resultado irá ser plotado em um só gráfico ou em três subplots em linha - `plotar_niveis(t_0, t_1, subplots=False)`
# * Gere `boxplots` para os dados em uma mesma escala de "y" compare o desempenho dos pedidores em termo de precisão e exatidão. Observe que o período mais transitório pode poluir o boxplot, tente removê-lo!

# %%
t = np.linspace(0, 100, 1000) # tempo de 0 a 100
nivel_inicial = 50 # nível em 50%
instante = 9

nivel_real = np.ones_like(t)*nivel_inicial 
nivel_real[t > instante] = 50 + 5*np.exp(-(t[t > instante] - instante)/5)*np.cos(np.pi*(t[t > instante])/12)

def medidor(valor, erro=0, bias=0):
    return valor + erro*np.random.randn(len(valor)) + bias*valor

LT01 = medidor(nivel_real, .05, .01)
LT02 = medidor(nivel_real, .10, -.01)
LT03 = medidor(nivel_real, .15)

plt.subplots(figsize = (15, 5))
plt.plot(t, LT01, '3',
         t, LT02, '3',
         t, LT03, '3',
         t, nivel_real, '--',
         alpha=.6)
plt.ylabel('Nível [%]')
plt.xlabel('t [min]')
plt.legend(['LT-01', 'LT-02', 'LT-03', 'Valor real'])
plt.show()

# %% [markdown]
# #### Exercício 7
# De acordo com o [g1](https://g1.globo.com/economia/noticia/2020/09/17/fome-no-brasil-em-5-anos-cresce-em-3-milhoes-o-no-de-pessoas-em-situacao-de-inseguranca-alimentar-grave-diz-ibge.ghtml), apesar de ter sido reduzida desde 2004, a situação da fome no Brasil começou a se agravar a partir de 2013:
#
# ![image](https://s2.glbimg.com/__3k-cr7UZSxaZhVUKECdRfKs54=/0x0:1340x490/984x0/smart/filters:strip_icc()/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2020/6/i/gVItuyTpOvB6BNotz6QA/vtzhh-font-style-vertical-align-inherit-font-style-vertical-align-inherit-n-mero-de-pessoas-que-passam-fome-no-brasil-font-font-.png)
#
# |Ano|Insegurança <br> alimentar [milhares]|
# |-|-:|
# |2004|14998|
# |2009|11292|
# |2013|7225|
# |2018|10284|
#
# De acordo com a [EBC](https://agenciabrasil.ebc.com.br/geral/noticia/2021-04/pesquisa-revela-que-19-milhoes-passaram-fome-no-brasil-no-fim-de-2020) o número só piora, chegando a 19 milhões de pessoas com insegurança alimentar grave ao final de 2020.
#
# * Complete o gráfico de barras horizontais criado pelo G1 acrescentando os dados de 2020.

# %% [markdown]
# #### Exercício 8
# Gere um gráfico de pizza com uma carteira de investimentos que possui:
# * LCA/LCI: R\$ 3000,00
# * Ações: R\$ 8000,00
# * CDB: R\$ 2000,00
# * Tesouro: R\$ 2500,00
# * Poupança: R\$ 12500,00

# %% [markdown]
# ## IV. Tutoriais
# ---
# O Matplotlib possui uma área a de [Tutoriais](https://matplotlib.org/stable/tutorials/index.html) e [Exemplos](https://matplotlib.org/stable/gallery/index.html) muito extensa, utilize como referência para fazer o exercício à seguir.
